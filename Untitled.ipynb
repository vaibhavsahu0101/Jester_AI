# %%
import pandas as pd

# %%
data = pd.read_excel('jester-data-2.xls', sep='\t', parse_dates=True, squeeze=True,index_col=0)

# %%
data.sort_index(inplace=True)
data=data.replace(99,0)

# %%
data
# Out:
#          Joke_1  Joke_2  Joke_3  Joke_4  Joke_5  Joke_6  Joke_7  Joke_8  \
# User_id
# 36         0.00    0.00    0.00    0.00    9.17    0.00   -9.90    2.48
# 36         0.00    0.00    0.00    0.00    3.25    0.00   -9.03   -9.66
# 36         0.00    0.00    0.00    0.00   -4.47    0.00   -9.32   -6.99
# 36         0.00    0.00    0.00    0.00   -9.81    0.00    0.92    3.20
# 36         0.00    0.00    0.00    0.00    4.76    0.00    4.90    1.26
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 100        7.82    3.74   -0.92    2.72    5.15    1.07    4.61    5.39
# 100       -3.20    1.36   -9.85   -5.97   -6.21    4.42    6.31    4.95
# 100        7.04    4.76   -2.14    1.07    7.23    6.89    5.24   -6.31
# 100       -3.74    8.69   -3.20   -8.11    6.65    0.34    8.40    9.08
# 100        8.59    9.03    8.74    8.35   -0.10    8.06    5.10    1.17
#
#          Joke_9  Joke_10  ...  Joke_91  Joke_92  Joke_93  Joke_94  Joke_95  \
# ...
